# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import regularizers
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
(x_train, _), (x_test, _) = fashion_mnist.load_data() # we don't need the labels
x_train = x_train.astype('float32') / 255. # normalise
x_test = x_test.astype('float32') / 255.

print(x_train.shape) # shape of input
print(x_test.shape)

x_train = x_train.reshape(( x_train.shape[0], np.prod(x_train.shape[1:]))) #flatten
x_test = x_test.reshape((x_test.shape[0], np.prod(x_test.shape[1:])))

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000, 784)
# (10000, 784)

# %%
image_dim =  784 # this is the size of our input image, 784
encoding_dim = 32 # this is the length of our encoded items.Compression of factor=784/32=24.5

# %%
input_image = Input(shape=(image_dim, )) # this is our input placeholder

encoded_image = Dense(encoding_dim, activation='relu',
                      activity_regularizer=regularizers.l1(10e-5))(input_image)# "encoded" is the encoded representation of the input
encoder = Model(input_image, encoded_image)

decoded_image = Dense(image_dim, activation='sigmoid')(encoded_image)# "decoded" is the lossy reconstruction of the input

autoencoder = Model(input_image, decoded_image) # this model maps an input to its reconstruction

# %%
encoded_input = Input(shape=(encoding_dim,))# create a placeholder for an encoded (32-dimensional) input

decoder_layer = autoencoder.layers[-1]# retrieve the last layer of the autoencoder model

decoder = Model(encoded_input, decoder_layer(encoded_input))# create the decoder model

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
checkpointer1 = ModelCheckpoint(filepath= 'model.weights.best.hdf5' , verbose =2, save_best_only =  True)
checkpointer2 = EarlyStopping(monitor='val_loss',
                              min_delta=0.0005,
                              patience=2,
                              verbose=2, mode='auto')

# %%
autoencoder.fit(x_train, x_train,
                epochs=500,
                batch_size=256,callbacks=[checkpointer1], verbose=2,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/500
#
# Epoch 00001: val_loss improved from 0.68544 to 0.68519, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6853 - val_loss: 0.6852
# Epoch 2/500
#
# Epoch 00002: val_loss improved from 0.68519 to 0.68494, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6851 - val_loss: 0.6849
# Epoch 3/500
#
# Epoch 00003: val_loss improved from 0.68494 to 0.68468, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6848 - val_loss: 0.6847
# Epoch 4/500
#
# Epoch 00004: val_loss improved from 0.68468 to 0.68441, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6845 - val_loss: 0.6844
# Epoch 5/500
#
# Epoch 00005: val_loss improved from 0.68441 to 0.68414, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6843 - val_loss: 0.6841
# Epoch 6/500
#
# Epoch 00006: val_loss improved from 0.68414 to 0.68385, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6840 - val_loss: 0.6839
# Epoch 7/500
#
# Epoch 00007: val_loss improved from 0.68385 to 0.68357, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6837 - val_loss: 0.6836
# Epoch 8/500
#
# Epoch 00008: val_loss improved from 0.68357 to 0.68327, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6834 - val_loss: 0.6833
# Epoch 9/500
#
# Epoch 00009: val_loss improved from 0.68327 to 0.68297, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6831 - val_loss: 0.6830
# Epoch 10/500
#
# Epoch 00010: val_loss improved from 0.68297 to 0.68266, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6828 - val_loss: 0.6827
# Epoch 11/500
#
# Epoch 00011: val_loss improved from 0.68266 to 0.68234, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6825 - val_loss: 0.6823
# Epoch 12/500
#
# Epoch 00012: val_loss improved from 0.68234 to 0.68201, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6822 - val_loss: 0.6820
# Epoch 13/500
#
# Epoch 00013: val_loss improved from 0.68201 to 0.68168, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6818 - val_loss: 0.6817
# Epoch 14/500
#
# Epoch 00014: val_loss improved from 0.68168 to 0.68133, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6815 - val_loss: 0.6813
# Epoch 15/500
#
# Epoch 00015: val_loss improved from 0.68133 to 0.68098, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6811 - val_loss: 0.6810
# Epoch 16/500
#
# Epoch 00016: val_loss improved from 0.68098 to 0.68062, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6808 - val_loss: 0.6806
# Epoch 17/500
#
# Epoch 00017: val_loss improved from 0.68062 to 0.68025, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6804 - val_loss: 0.6803
# Epoch 18/500
#
# Epoch 00018: val_loss improved from 0.68025 to 0.67987, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6800 - val_loss: 0.6799
# Epoch 19/500
#
# Epoch 00019: val_loss improved from 0.67987 to 0.67948, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6797 - val_loss: 0.6795
# Epoch 20/500
#
# Epoch 00020: val_loss improved from 0.67948 to 0.67908, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6793 - val_loss: 0.6791
# Epoch 21/500
#
# Epoch 00021: val_loss improved from 0.67908 to 0.67868, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6789 - val_loss: 0.6787
# Epoch 22/500
#
# Epoch 00022: val_loss improved from 0.67868 to 0.67826, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6784 - val_loss: 0.6783
# Epoch 23/500
#
# Epoch 00023: val_loss improved from 0.67826 to 0.67783, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6780 - val_loss: 0.6778
# Epoch 24/500
#
# Epoch 00024: val_loss improved from 0.67783 to 0.67739, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6776 - val_loss: 0.6774
# Epoch 25/500
#
# Epoch 00025: val_loss improved from 0.67739 to 0.67694, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6771 - val_loss: 0.6769
# Epoch 26/500
#
# Epoch 00026: val_loss improved from 0.67694 to 0.67648, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6767 - val_loss: 0.6765
# Epoch 27/500
#
# Epoch 00027: val_loss improved from 0.67648 to 0.67601, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6762 - val_loss: 0.6760
# Epoch 28/500
#
# Epoch 00028: val_loss improved from 0.67601 to 0.67552, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6757 - val_loss: 0.6755
# Epoch 29/500
#
# Epoch 00029: val_loss improved from 0.67552 to 0.67503, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6753 - val_loss: 0.6750
# Epoch 30/500
#
# Epoch 00030: val_loss improved from 0.67503 to 0.67452, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6748 - val_loss: 0.6745
# Epoch 31/500
#
# Epoch 00031: val_loss improved from 0.67452 to 0.67400, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6742 - val_loss: 0.6740
# Epoch 32/500
#
# Epoch 00032: val_loss improved from 0.67400 to 0.67347, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6737 - val_loss: 0.6735
# Epoch 33/500
#
# Epoch 00033: val_loss improved from 0.67347 to 0.67293, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6732 - val_loss: 0.6729
# Epoch 34/500
#
# Epoch 00034: val_loss improved from 0.67293 to 0.67237, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6726 - val_loss: 0.6724
# Epoch 35/500
#
# Epoch 00035: val_loss improved from 0.67237 to 0.67181, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6721 - val_loss: 0.6718
# Epoch 36/500
#
# Epoch 00036: val_loss improved from 0.67181 to 0.67122, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6715 - val_loss: 0.6712
# Epoch 37/500
#
# Epoch 00037: val_loss improved from 0.67122 to 0.67063, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6709 - val_loss: 0.6706
# Epoch 38/500
#
# Epoch 00038: val_loss improved from 0.67063 to 0.67002, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6703 - val_loss: 0.6700
# Epoch 39/500
#
# Epoch 00039: val_loss improved from 0.67002 to 0.66940, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6697 - val_loss: 0.6694
# Epoch 40/500
#
# Epoch 00040: val_loss improved from 0.66940 to 0.66876, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6691 - val_loss: 0.6688
# Epoch 41/500
#
# Epoch 00041: val_loss improved from 0.66876 to 0.66811, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6684 - val_loss: 0.6681
# Epoch 42/500
#
# Epoch 00042: val_loss improved from 0.66811 to 0.66745, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6678 - val_loss: 0.6675
# Epoch 43/500
#
# Epoch 00043: val_loss improved from 0.66745 to 0.66677, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6671 - val_loss: 0.6668
# Epoch 44/500
#
# Epoch 00044: val_loss improved from 0.66677 to 0.66608, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6664 - val_loss: 0.6661
# Epoch 45/500
#
# Epoch 00045: val_loss improved from 0.66608 to 0.66538, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6657 - val_loss: 0.6654
# Epoch 46/500
#
# Epoch 00046: val_loss improved from 0.66538 to 0.66466, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6650 - val_loss: 0.6647
# Epoch 47/500
#
# Epoch 00047: val_loss improved from 0.66466 to 0.66392, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6643 - val_loss: 0.6639
# Epoch 48/500
#
# Epoch 00048: val_loss improved from 0.66392 to 0.66317, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6635 - val_loss: 0.6632
# Epoch 49/500
#
# Epoch 00049: val_loss improved from 0.66317 to 0.66241, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6628 - val_loss: 0.6624
# Epoch 50/500
#
# Epoch 00050: val_loss improved from 0.66241 to 0.66163, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6620 - val_loss: 0.6616
# Epoch 51/500
#
# Epoch 00051: val_loss improved from 0.66163 to 0.66083, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6612 - val_loss: 0.6608
# Epoch 52/500
#
# Epoch 00052: val_loss improved from 0.66083 to 0.66002, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6604 - val_loss: 0.6600
# Epoch 53/500
#
# Epoch 00053: val_loss improved from 0.66002 to 0.65920, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6596 - val_loss: 0.6592
# Epoch 54/500
#
# Epoch 00054: val_loss improved from 0.65920 to 0.65836, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6587 - val_loss: 0.6584
# Epoch 55/500
#
# Epoch 00055: val_loss improved from 0.65836 to 0.65750, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6579 - val_loss: 0.6575
# Epoch 56/500
#
# Epoch 00056: val_loss improved from 0.65750 to 0.65663, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6570 - val_loss: 0.6566
# Epoch 57/500
#
# Epoch 00057: val_loss improved from 0.65663 to 0.65575, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6561 - val_loss: 0.6557
# Epoch 58/500
#
# Epoch 00058: val_loss improved from 0.65575 to 0.65484, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6552 - val_loss: 0.6548
# Epoch 59/500
#
# Epoch 00059: val_loss improved from 0.65484 to 0.65393, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6543 - val_loss: 0.6539
# Epoch 60/500
#
# Epoch 00060: val_loss improved from 0.65393 to 0.65300, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6534 - val_loss: 0.6530
# Epoch 61/500
#
# Epoch 00061: val_loss improved from 0.65300 to 0.65205, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6525 - val_loss: 0.6521
# Epoch 62/500
#
# Epoch 00062: val_loss improved from 0.65205 to 0.65109, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6515 - val_loss: 0.6511
# Epoch 63/500
#
# Epoch 00063: val_loss improved from 0.65109 to 0.65012, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6506 - val_loss: 0.6501
# Epoch 64/500
#
# Epoch 00064: val_loss improved from 0.65012 to 0.64913, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6496 - val_loss: 0.6491
# Epoch 65/500
#
# Epoch 00065: val_loss improved from 0.64913 to 0.64813, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6486 - val_loss: 0.6481
# Epoch 66/500
#
# Epoch 00066: val_loss improved from 0.64813 to 0.64711, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6476 - val_loss: 0.6471
# Epoch 67/500
#
# Epoch 00067: val_loss improved from 0.64711 to 0.64608, saving model to model.weights.best.hdf5
# 60000/60000 - 2s - loss: 0.6465 - val_loss: 0.6461
# Epoch 68/500
#
# Epoch 00068: val_loss improved from 0.64608 to 0.64504, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6455 - val_loss: 0.6450
# Epoch 69/500
#
# Epoch 00069: val_loss improved from 0.64504 to 0.64398, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6444 - val_loss: 0.6440
# Epoch 70/500
#
# Epoch 00070: val_loss improved from 0.64398 to 0.64291, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6434 - val_loss: 0.6429
# Epoch 71/500
#
# Epoch 00071: val_loss improved from 0.64291 to 0.64183, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6423 - val_loss: 0.6418
# Epoch 72/500
#
# Epoch 00072: val_loss improved from 0.64183 to 0.64073, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6412 - val_loss: 0.6407
# Epoch 73/500
#
# Epoch 00073: val_loss improved from 0.64073 to 0.63962, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6401 - val_loss: 0.6396
# Epoch 74/500
#
# Epoch 00074: val_loss improved from 0.63962 to 0.63850, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6390 - val_loss: 0.6385
# Epoch 75/500
#
# Epoch 00075: val_loss improved from 0.63850 to 0.63737, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6379 - val_loss: 0.6374
# Epoch 76/500
#
# Epoch 00076: val_loss improved from 0.63737 to 0.63623, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6367 - val_loss: 0.6362
# Epoch 77/500
#
# Epoch 00077: val_loss improved from 0.63623 to 0.63507, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6356 - val_loss: 0.6351
# Epoch 78/500
#
# Epoch 00078: val_loss improved from 0.63507 to 0.63391, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6344 - val_loss: 0.6339
# Epoch 79/500
#
# Epoch 00079: val_loss improved from 0.63391 to 0.63274, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6332 - val_loss: 0.6327
# Epoch 80/500
#
# Epoch 00080: val_loss improved from 0.63274 to 0.63155, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6321 - val_loss: 0.6316
# Epoch 81/500
#
# Epoch 00081: val_loss improved from 0.63155 to 0.63036, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6309 - val_loss: 0.6304
# Epoch 82/500
#
# Epoch 00082: val_loss improved from 0.63036 to 0.62916, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6297 - val_loss: 0.6292
# Epoch 83/500
#
# Epoch 00083: val_loss improved from 0.62916 to 0.62795, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6285 - val_loss: 0.6280
# Epoch 84/500
#
# Epoch 00084: val_loss improved from 0.62795 to 0.62674, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6273 - val_loss: 0.6267
# Epoch 85/500
#
# Epoch 00085: val_loss improved from 0.62674 to 0.62552, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6260 - val_loss: 0.6255
# Epoch 86/500
#
# Epoch 00086: val_loss improved from 0.62552 to 0.62429, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6248 - val_loss: 0.6243
# Epoch 87/500
#
# Epoch 00087: val_loss improved from 0.62429 to 0.62305, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6236 - val_loss: 0.6231
# Epoch 88/500
#
# Epoch 00088: val_loss improved from 0.62305 to 0.62181, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6223 - val_loss: 0.6218
# Epoch 89/500
#
# Epoch 00089: val_loss improved from 0.62181 to 0.62057, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6211 - val_loss: 0.6206
# Epoch 90/500
#
# Epoch 00090: val_loss improved from 0.62057 to 0.61932, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6198 - val_loss: 0.6193
# Epoch 91/500
#
# Epoch 00091: val_loss improved from 0.61932 to 0.61807, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6186 - val_loss: 0.6181
# Epoch 92/500
#
# Epoch 00092: val_loss improved from 0.61807 to 0.61681, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6173 - val_loss: 0.6168
# Epoch 93/500
#
# Epoch 00093: val_loss improved from 0.61681 to 0.61556, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6161 - val_loss: 0.6156
# Epoch 94/500
#
# Epoch 00094: val_loss improved from 0.61556 to 0.61430, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6148 - val_loss: 0.6143
# Epoch 95/500
#
# Epoch 00095: val_loss improved from 0.61430 to 0.61304, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6136 - val_loss: 0.6130
# Epoch 96/500
#
# Epoch 00096: val_loss improved from 0.61304 to 0.61178, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6123 - val_loss: 0.6118
# Epoch 97/500
#
# Epoch 00097: val_loss improved from 0.61178 to 0.61052, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6110 - val_loss: 0.6105
# Epoch 98/500
#
# Epoch 00098: val_loss improved from 0.61052 to 0.60926, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6098 - val_loss: 0.6093
# Epoch 99/500
#
# Epoch 00099: val_loss improved from 0.60926 to 0.60800, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6085 - val_loss: 0.6080
# Epoch 100/500
#
# Epoch 00100: val_loss improved from 0.60800 to 0.60674, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6072 - val_loss: 0.6067
# Epoch 101/500
#
# Epoch 00101: val_loss improved from 0.60674 to 0.60549, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6060 - val_loss: 0.6055
# Epoch 102/500
#
# Epoch 00102: val_loss improved from 0.60549 to 0.60424, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6047 - val_loss: 0.6042
# Epoch 103/500
#
# Epoch 00103: val_loss improved from 0.60424 to 0.60299, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6035 - val_loss: 0.6030
# Epoch 104/500
#
# Epoch 00104: val_loss improved from 0.60299 to 0.60175, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6022 - val_loss: 0.6018
# Epoch 105/500
#
# Epoch 00105: val_loss improved from 0.60175 to 0.60051, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.6010 - val_loss: 0.6005
# Epoch 106/500
#
# Epoch 00106: val_loss improved from 0.60051 to 0.59928, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5998 - val_loss: 0.5993
# Epoch 107/500
#
# Epoch 00107: val_loss improved from 0.59928 to 0.59805, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5985 - val_loss: 0.5981
# Epoch 108/500
#
# Epoch 00108: val_loss improved from 0.59805 to 0.59683, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5973 - val_loss: 0.5968
# Epoch 109/500
#
# Epoch 00109: val_loss improved from 0.59683 to 0.59562, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5961 - val_loss: 0.5956
# Epoch 110/500
#
# Epoch 00110: val_loss improved from 0.59562 to 0.59441, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5949 - val_loss: 0.5944
# Epoch 111/500
#
# Epoch 00111: val_loss improved from 0.59441 to 0.59322, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5937 - val_loss: 0.5932
# Epoch 112/500
#
# Epoch 00112: val_loss improved from 0.59322 to 0.59203, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5925 - val_loss: 0.5920
# Epoch 113/500
#
# Epoch 00113: val_loss improved from 0.59203 to 0.59085, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5913 - val_loss: 0.5908
# Epoch 114/500
#
# Epoch 00114: val_loss improved from 0.59085 to 0.58968, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5901 - val_loss: 0.5897
# Epoch 115/500
#
# Epoch 00115: val_loss improved from 0.58968 to 0.58851, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5889 - val_loss: 0.5885
# Epoch 116/500
#
# Epoch 00116: val_loss improved from 0.58851 to 0.58736, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5878 - val_loss: 0.5874
# Epoch 117/500
#
# Epoch 00117: val_loss improved from 0.58736 to 0.58622, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5866 - val_loss: 0.5862
# Epoch 118/500
#
# Epoch 00118: val_loss improved from 0.58622 to 0.58509, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5855 - val_loss: 0.5851
# Epoch 119/500
#
# Epoch 00119: val_loss improved from 0.58509 to 0.58397, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5843 - val_loss: 0.5840
# Epoch 120/500
#
# Epoch 00120: val_loss improved from 0.58397 to 0.58286, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5832 - val_loss: 0.5829
# Epoch 121/500
#
# Epoch 00121: val_loss improved from 0.58286 to 0.58177, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5821 - val_loss: 0.5818
# Epoch 122/500
#
# Epoch 00122: val_loss improved from 0.58177 to 0.58068, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5810 - val_loss: 0.5807
# Epoch 123/500
#
# Epoch 00123: val_loss improved from 0.58068 to 0.57961, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5799 - val_loss: 0.5796
# Epoch 124/500
#
# Epoch 00124: val_loss improved from 0.57961 to 0.57855, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5789 - val_loss: 0.5786
# Epoch 125/500
#
# Epoch 00125: val_loss improved from 0.57855 to 0.57751, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5778 - val_loss: 0.5775
# Epoch 126/500
#
# Epoch 00126: val_loss improved from 0.57751 to 0.57647, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5768 - val_loss: 0.5765
# Epoch 127/500
#
# Epoch 00127: val_loss improved from 0.57647 to 0.57545, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5758 - val_loss: 0.5755
# Epoch 128/500
#
# Epoch 00128: val_loss improved from 0.57545 to 0.57445, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5747 - val_loss: 0.5744
# Epoch 129/500
#
# Epoch 00129: val_loss improved from 0.57445 to 0.57346, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5737 - val_loss: 0.5735
# Epoch 130/500
#
# Epoch 00130: val_loss improved from 0.57346 to 0.57248, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5727 - val_loss: 0.5725
# Epoch 131/500
#
# Epoch 00131: val_loss improved from 0.57248 to 0.57151, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5718 - val_loss: 0.5715
# Epoch 132/500
#
# Epoch 00132: val_loss improved from 0.57151 to 0.57056, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5708 - val_loss: 0.5706
# Epoch 133/500
#
# Epoch 00133: val_loss improved from 0.57056 to 0.56962, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5699 - val_loss: 0.5696
# Epoch 134/500
#
# Epoch 00134: val_loss improved from 0.56962 to 0.56870, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5689 - val_loss: 0.5687
# Epoch 135/500
#
# Epoch 00135: val_loss improved from 0.56870 to 0.56779, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5680 - val_loss: 0.5678
# Epoch 136/500
#
# Epoch 00136: val_loss improved from 0.56779 to 0.56690, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5671 - val_loss: 0.5669
# Epoch 137/500
#
# Epoch 00137: val_loss improved from 0.56690 to 0.56602, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5662 - val_loss: 0.5660
# Epoch 138/500
#
# Epoch 00138: val_loss improved from 0.56602 to 0.56515, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5653 - val_loss: 0.5652
# Epoch 139/500
#
# Epoch 00139: val_loss improved from 0.56515 to 0.56430, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5645 - val_loss: 0.5643
# Epoch 140/500
#
# Epoch 00140: val_loss improved from 0.56430 to 0.56346, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5636 - val_loss: 0.5635
# Epoch 141/500
#
# Epoch 00141: val_loss improved from 0.56346 to 0.56264, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5628 - val_loss: 0.5626
# Epoch 142/500
#
# Epoch 00142: val_loss improved from 0.56264 to 0.56183, saving model to model.weights.best.hdf5
# 60000/60000 - 2s - loss: 0.5620 - val_loss: 0.5618
# Epoch 143/500
#
# Epoch 00143: val_loss improved from 0.56183 to 0.56103, saving model to model.weights.best.hdf5
# 60000/60000 - 2s - loss: 0.5612 - val_loss: 0.5610
# Epoch 144/500
#
# Epoch 00144: val_loss improved from 0.56103 to 0.56025, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5604 - val_loss: 0.5603
# Epoch 145/500
#
# Epoch 00145: val_loss improved from 0.56025 to 0.55949, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5596 - val_loss: 0.5595
# Epoch 146/500
#
# Epoch 00146: val_loss improved from 0.55949 to 0.55873, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5588 - val_loss: 0.5587
# Epoch 147/500
#
# Epoch 00147: val_loss improved from 0.55873 to 0.55799, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5581 - val_loss: 0.5580
# Epoch 148/500
#
# Epoch 00148: val_loss improved from 0.55799 to 0.55727, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5574 - val_loss: 0.5573
# Epoch 149/500
#
# Epoch 00149: val_loss improved from 0.55727 to 0.55656, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5566 - val_loss: 0.5566
# Epoch 150/500
#
# Epoch 00150: val_loss improved from 0.55656 to 0.55586, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5559 - val_loss: 0.5559
# Epoch 151/500
#
# Epoch 00151: val_loss improved from 0.55586 to 0.55517, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5552 - val_loss: 0.5552
# Epoch 152/500
#
# Epoch 00152: val_loss improved from 0.55517 to 0.55450, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5546 - val_loss: 0.5545
# Epoch 153/500
#
# Epoch 00153: val_loss improved from 0.55450 to 0.55384, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5539 - val_loss: 0.5538
# Epoch 154/500
#
# Epoch 00154: val_loss improved from 0.55384 to 0.55320, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5532 - val_loss: 0.5532
# Epoch 155/500
#
# Epoch 00155: val_loss improved from 0.55320 to 0.55256, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5526 - val_loss: 0.5526
# Epoch 156/500
#
# Epoch 00156: val_loss improved from 0.55256 to 0.55194, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5520 - val_loss: 0.5519
# Epoch 157/500
#
# Epoch 00157: val_loss improved from 0.55194 to 0.55134, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5513 - val_loss: 0.5513
# Epoch 158/500
#
# Epoch 00158: val_loss improved from 0.55134 to 0.55074, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5507 - val_loss: 0.5507
# Epoch 159/500
#
# Epoch 00159: val_loss improved from 0.55074 to 0.55016, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5501 - val_loss: 0.5502
# Epoch 160/500
#
# Epoch 00160: val_loss improved from 0.55016 to 0.54958, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5496 - val_loss: 0.5496
# Epoch 161/500
#
# Epoch 00161: val_loss improved from 0.54958 to 0.54902, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5490 - val_loss: 0.5490
# Epoch 162/500
#
# Epoch 00162: val_loss improved from 0.54902 to 0.54848, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5484 - val_loss: 0.5485
# Epoch 163/500
#
# Epoch 00163: val_loss improved from 0.54848 to 0.54794, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5479 - val_loss: 0.5479
# Epoch 164/500
#
# Epoch 00164: val_loss improved from 0.54794 to 0.54741, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5474 - val_loss: 0.5474
# Epoch 165/500
#
# Epoch 00165: val_loss improved from 0.54741 to 0.54690, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5468 - val_loss: 0.5469
# Epoch 166/500
#
# Epoch 00166: val_loss improved from 0.54690 to 0.54639, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5463 - val_loss: 0.5464
# Epoch 167/500
#
# Epoch 00167: val_loss improved from 0.54639 to 0.54590, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5458 - val_loss: 0.5459
# Epoch 168/500
#
# Epoch 00168: val_loss improved from 0.54590 to 0.54542, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5453 - val_loss: 0.5454
# Epoch 169/500
#
# Epoch 00169: val_loss improved from 0.54542 to 0.54495, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5449 - val_loss: 0.5449
# Epoch 170/500
#
# Epoch 00170: val_loss improved from 0.54495 to 0.54448, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5444 - val_loss: 0.5445
# Epoch 171/500
#
# Epoch 00171: val_loss improved from 0.54448 to 0.54403, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5439 - val_loss: 0.5440
# Epoch 172/500
#
# Epoch 00172: val_loss improved from 0.54403 to 0.54359, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5435 - val_loss: 0.5436
# Epoch 173/500
#
# Epoch 00173: val_loss improved from 0.54359 to 0.54315, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5430 - val_loss: 0.5432
# Epoch 174/500
#
# Epoch 00174: val_loss improved from 0.54315 to 0.54273, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5426 - val_loss: 0.5427
# Epoch 175/500
#
# Epoch 00175: val_loss improved from 0.54273 to 0.54232, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5422 - val_loss: 0.5423
# Epoch 176/500
#
# Epoch 00176: val_loss improved from 0.54232 to 0.54191, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5418 - val_loss: 0.5419
# Epoch 177/500
#
# Epoch 00177: val_loss improved from 0.54191 to 0.54151, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5414 - val_loss: 0.5415
# Epoch 178/500
#
# Epoch 00178: val_loss improved from 0.54151 to 0.54112, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5410 - val_loss: 0.5411
# Epoch 179/500
#
# Epoch 00179: val_loss improved from 0.54112 to 0.54074, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5406 - val_loss: 0.5407
# Epoch 180/500
#
# Epoch 00180: val_loss improved from 0.54074 to 0.54037, saving model to model.weights.best.hdf5
# 60000/60000 - 2s - loss: 0.5402 - val_loss: 0.5404
# Epoch 181/500
#
# Epoch 00181: val_loss improved from 0.54037 to 0.54001, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5398 - val_loss: 0.5400
# Epoch 182/500
#
# Epoch 00182: val_loss improved from 0.54001 to 0.53965, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5395 - val_loss: 0.5397
# Epoch 183/500
#
# Epoch 00183: val_loss improved from 0.53965 to 0.53931, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5391 - val_loss: 0.5393
# Epoch 184/500
#
# Epoch 00184: val_loss improved from 0.53931 to 0.53897, saving model to model.weights.best.hdf5
# 60000/60000 - 2s - loss: 0.5388 - val_loss: 0.5390
# Epoch 185/500
#
# Epoch 00185: val_loss improved from 0.53897 to 0.53863, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5385 - val_loss: 0.5386
# Epoch 186/500
#
# Epoch 00186: val_loss improved from 0.53863 to 0.53831, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5381 - val_loss: 0.5383
# Epoch 187/500
#
# Epoch 00187: val_loss improved from 0.53831 to 0.53799, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5378 - val_loss: 0.5380
# Epoch 188/500
#
# Epoch 00188: val_loss improved from 0.53799 to 0.53768, saving model to model.weights.best.hdf5
# 60000/60000 - 2s - loss: 0.5375 - val_loss: 0.5377
# Epoch 189/500
#
# Epoch 00189: val_loss improved from 0.53768 to 0.53737, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5372 - val_loss: 0.5374
# Epoch 190/500
#
# Epoch 00190: val_loss improved from 0.53737 to 0.53707, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5369 - val_loss: 0.5371
# Epoch 191/500
#
# Epoch 00191: val_loss improved from 0.53707 to 0.53678, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5366 - val_loss: 0.5368
# Epoch 192/500
#
# Epoch 00192: val_loss improved from 0.53678 to 0.53649, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5363 - val_loss: 0.5365
# Epoch 193/500
#
# Epoch 00193: val_loss improved from 0.53649 to 0.53621, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5360 - val_loss: 0.5362
# Epoch 194/500
#
# Epoch 00194: val_loss improved from 0.53621 to 0.53594, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5357 - val_loss: 0.5359
# Epoch 195/500
#
# Epoch 00195: val_loss improved from 0.53594 to 0.53567, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5354 - val_loss: 0.5357
# Epoch 196/500
#
# Epoch 00196: val_loss improved from 0.53567 to 0.53541, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5352 - val_loss: 0.5354
# Epoch 197/500
#
# Epoch 00197: val_loss improved from 0.53541 to 0.53515, saving model to model.weights.best.hdf5
# 60000/60000 - 2s - loss: 0.5349 - val_loss: 0.5352
# Epoch 198/500
#
# Epoch 00198: val_loss improved from 0.53515 to 0.53490, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5347 - val_loss: 0.5349
# Epoch 199/500
#
# Epoch 00199: val_loss improved from 0.53490 to 0.53465, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5344 - val_loss: 0.5347
# Epoch 200/500
#
# Epoch 00200: val_loss improved from 0.53465 to 0.53441, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5342 - val_loss: 0.5344
# Epoch 201/500
#
# Epoch 00201: val_loss improved from 0.53441 to 0.53417, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5339 - val_loss: 0.5342
# Epoch 202/500
#
# Epoch 00202: val_loss improved from 0.53417 to 0.53394, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5337 - val_loss: 0.5339
# Epoch 203/500
#
# Epoch 00203: val_loss improved from 0.53394 to 0.53372, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5335 - val_loss: 0.5337
# Epoch 204/500
#
# Epoch 00204: val_loss improved from 0.53372 to 0.53349, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5332 - val_loss: 0.5335
# Epoch 205/500
#
# Epoch 00205: val_loss improved from 0.53349 to 0.53328, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5330 - val_loss: 0.5333
# Epoch 206/500
#
# Epoch 00206: val_loss improved from 0.53328 to 0.53306, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5328 - val_loss: 0.5331
# Epoch 207/500
#
# Epoch 00207: val_loss improved from 0.53306 to 0.53285, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5326 - val_loss: 0.5329
# Epoch 208/500
#
# Epoch 00208: val_loss improved from 0.53285 to 0.53265, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5324 - val_loss: 0.5326
# Epoch 209/500
#
# Epoch 00209: val_loss improved from 0.53265 to 0.53245, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5322 - val_loss: 0.5324
# Epoch 210/500
#
# Epoch 00210: val_loss improved from 0.53245 to 0.53225, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5320 - val_loss: 0.5323
# Epoch 211/500
#
# Epoch 00211: val_loss improved from 0.53225 to 0.53206, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5318 - val_loss: 0.5321
# Epoch 212/500
#
# Epoch 00212: val_loss improved from 0.53206 to 0.53187, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5316 - val_loss: 0.5319
# Epoch 213/500
#
# Epoch 00213: val_loss improved from 0.53187 to 0.53168, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5314 - val_loss: 0.5317
# Epoch 214/500
#
# Epoch 00214: val_loss improved from 0.53168 to 0.53150, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5312 - val_loss: 0.5315
# Epoch 215/500
#
# Epoch 00215: val_loss improved from 0.53150 to 0.53132, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5310 - val_loss: 0.5313
# Epoch 216/500
#
# Epoch 00216: val_loss improved from 0.53132 to 0.53115, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5309 - val_loss: 0.5311
# Epoch 217/500
#
# Epoch 00217: val_loss improved from 0.53115 to 0.53098, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5307 - val_loss: 0.5310
# Epoch 218/500
#
# Epoch 00218: val_loss improved from 0.53098 to 0.53081, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5305 - val_loss: 0.5308
# Epoch 219/500
#
# Epoch 00219: val_loss improved from 0.53081 to 0.53064, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5303 - val_loss: 0.5306
# Epoch 220/500
#
# Epoch 00220: val_loss improved from 0.53064 to 0.53048, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5302 - val_loss: 0.5305
# Epoch 221/500
#
# Epoch 00221: val_loss improved from 0.53048 to 0.53032, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5300 - val_loss: 0.5303
# Epoch 222/500
#
# Epoch 00222: val_loss improved from 0.53032 to 0.53016, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5299 - val_loss: 0.5302
# Epoch 223/500
#
# Epoch 00223: val_loss improved from 0.53016 to 0.53001, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5297 - val_loss: 0.5300
# Epoch 224/500
#
# Epoch 00224: val_loss improved from 0.53001 to 0.52986, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5296 - val_loss: 0.5299
# Epoch 225/500
#
# Epoch 00225: val_loss improved from 0.52986 to 0.52971, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5294 - val_loss: 0.5297
# Epoch 226/500
#
# Epoch 00226: val_loss improved from 0.52971 to 0.52956, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5293 - val_loss: 0.5296
# Epoch 227/500
#
# Epoch 00227: val_loss improved from 0.52956 to 0.52942, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5291 - val_loss: 0.5294
# Epoch 228/500
#
# Epoch 00228: val_loss improved from 0.52942 to 0.52928, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5290 - val_loss: 0.5293
# Epoch 229/500
#
# Epoch 00229: val_loss improved from 0.52928 to 0.52914, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5288 - val_loss: 0.5291
# Epoch 230/500
#
# Epoch 00230: val_loss improved from 0.52914 to 0.52900, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5287 - val_loss: 0.5290
# Epoch 231/500
#
# Epoch 00231: val_loss improved from 0.52900 to 0.52887, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5286 - val_loss: 0.5289
# Epoch 232/500
#
# Epoch 00232: val_loss improved from 0.52887 to 0.52874, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5284 - val_loss: 0.5287
# Epoch 233/500
#
# Epoch 00233: val_loss improved from 0.52874 to 0.52861, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5283 - val_loss: 0.5286
# Epoch 234/500
#
# Epoch 00234: val_loss improved from 0.52861 to 0.52848, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5282 - val_loss: 0.5285
# Epoch 235/500
#
# Epoch 00235: val_loss improved from 0.52848 to 0.52836, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5280 - val_loss: 0.5284
# Epoch 236/500
#
# Epoch 00236: val_loss improved from 0.52836 to 0.52823, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5279 - val_loss: 0.5282
# Epoch 237/500
#
# Epoch 00237: val_loss improved from 0.52823 to 0.52811, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5278 - val_loss: 0.5281
# Epoch 238/500
#
# Epoch 00238: val_loss improved from 0.52811 to 0.52799, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5277 - val_loss: 0.5280
# Epoch 239/500
#
# Epoch 00239: val_loss improved from 0.52799 to 0.52787, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5275 - val_loss: 0.5279
# Epoch 240/500
#
# Epoch 00240: val_loss improved from 0.52787 to 0.52776, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5274 - val_loss: 0.5278
# Epoch 241/500
#
# Epoch 00241: val_loss improved from 0.52776 to 0.52764, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5273 - val_loss: 0.5276
# Epoch 242/500
#
# Epoch 00242: val_loss improved from 0.52764 to 0.52753, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5272 - val_loss: 0.5275
# Epoch 243/500
#
# Epoch 00243: val_loss improved from 0.52753 to 0.52742, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5271 - val_loss: 0.5274
# Epoch 244/500
#
# Epoch 00244: val_loss improved from 0.52742 to 0.52731, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5270 - val_loss: 0.5273
# Epoch 245/500
#
# Epoch 00245: val_loss improved from 0.52731 to 0.52720, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5269 - val_loss: 0.5272
# Epoch 246/500
#
# Epoch 00246: val_loss improved from 0.52720 to 0.52709, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5268 - val_loss: 0.5271
# Epoch 247/500
#
# Epoch 00247: val_loss improved from 0.52709 to 0.52699, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5267 - val_loss: 0.5270
# Epoch 248/500
#
# Epoch 00248: val_loss improved from 0.52699 to 0.52688, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5265 - val_loss: 0.5269
# Epoch 249/500
#
# Epoch 00249: val_loss improved from 0.52688 to 0.52678, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5264 - val_loss: 0.5268
# Epoch 250/500
#
# Epoch 00250: val_loss improved from 0.52678 to 0.52668, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5263 - val_loss: 0.5267
# Epoch 251/500
#
# Epoch 00251: val_loss improved from 0.52668 to 0.52658, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5262 - val_loss: 0.5266
# Epoch 252/500
#
# Epoch 00252: val_loss improved from 0.52658 to 0.52648, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5261 - val_loss: 0.5265
# Epoch 253/500
#
# Epoch 00253: val_loss improved from 0.52648 to 0.52639, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5260 - val_loss: 0.5264
# Epoch 254/500
#
# Epoch 00254: val_loss improved from 0.52639 to 0.52629, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5259 - val_loss: 0.5263
# Epoch 255/500
#
# Epoch 00255: val_loss improved from 0.52629 to 0.52620, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5259 - val_loss: 0.5262
# Epoch 256/500
#
# Epoch 00256: val_loss improved from 0.52620 to 0.52610, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5258 - val_loss: 0.5261
# Epoch 257/500
#
# Epoch 00257: val_loss improved from 0.52610 to 0.52601, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5257 - val_loss: 0.5260
# Epoch 258/500
#
# Epoch 00258: val_loss improved from 0.52601 to 0.52592, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5256 - val_loss: 0.5259
# Epoch 259/500
#
# Epoch 00259: val_loss improved from 0.52592 to 0.52583, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5255 - val_loss: 0.5258
# Epoch 260/500
#
# Epoch 00260: val_loss improved from 0.52583 to 0.52574, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5254 - val_loss: 0.5257
# Epoch 261/500
#
# Epoch 00261: val_loss improved from 0.52574 to 0.52565, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5253 - val_loss: 0.5257
# Epoch 262/500
#
# Epoch 00262: val_loss improved from 0.52565 to 0.52556, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5252 - val_loss: 0.5256
# Epoch 263/500
#
# Epoch 00263: val_loss improved from 0.52556 to 0.52548, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5251 - val_loss: 0.5255
# Epoch 264/500
#
# Epoch 00264: val_loss improved from 0.52548 to 0.52539, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5250 - val_loss: 0.5254
# Epoch 265/500
#
# Epoch 00265: val_loss improved from 0.52539 to 0.52531, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5250 - val_loss: 0.5253
# Epoch 266/500
#
# Epoch 00266: val_loss improved from 0.52531 to 0.52522, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5249 - val_loss: 0.5252
# Epoch 267/500
#
# Epoch 00267: val_loss improved from 0.52522 to 0.52514, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5248 - val_loss: 0.5251
# Epoch 268/500
#
# Epoch 00268: val_loss improved from 0.52514 to 0.52506, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5247 - val_loss: 0.5251
# Epoch 269/500
#
# Epoch 00269: val_loss improved from 0.52506 to 0.52498, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5246 - val_loss: 0.5250
# Epoch 270/500
#
# Epoch 00270: val_loss improved from 0.52498 to 0.52490, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5245 - val_loss: 0.5249
# Epoch 271/500
#
# Epoch 00271: val_loss improved from 0.52490 to 0.52482, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5245 - val_loss: 0.5248
# Epoch 272/500
#
# Epoch 00272: val_loss improved from 0.52482 to 0.52474, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5244 - val_loss: 0.5247
# Epoch 273/500
#
# Epoch 00273: val_loss improved from 0.52474 to 0.52467, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5243 - val_loss: 0.5247
# Epoch 274/500
#
# Epoch 00274: val_loss improved from 0.52467 to 0.52459, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5242 - val_loss: 0.5246
# Epoch 275/500
#
# Epoch 00275: val_loss improved from 0.52459 to 0.52451, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5242 - val_loss: 0.5245
# Epoch 276/500
#
# Epoch 00276: val_loss improved from 0.52451 to 0.52444, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5241 - val_loss: 0.5244
# Epoch 277/500
#
# Epoch 00277: val_loss improved from 0.52444 to 0.52436, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5240 - val_loss: 0.5244
# Epoch 278/500
#
# Epoch 00278: val_loss improved from 0.52436 to 0.52429, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5239 - val_loss: 0.5243
# Epoch 279/500
#
# Epoch 00279: val_loss improved from 0.52429 to 0.52421, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5239 - val_loss: 0.5242
# Epoch 280/500
#
# Epoch 00280: val_loss improved from 0.52421 to 0.52414, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5238 - val_loss: 0.5241
# Epoch 281/500
#
# Epoch 00281: val_loss improved from 0.52414 to 0.52407, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5237 - val_loss: 0.5241
# Epoch 282/500
#
# Epoch 00282: val_loss improved from 0.52407 to 0.52400, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5236 - val_loss: 0.5240
# Epoch 283/500
#
# Epoch 00283: val_loss improved from 0.52400 to 0.52393, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5236 - val_loss: 0.5239
# Epoch 284/500
#
# Epoch 00284: val_loss improved from 0.52393 to 0.52386, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5235 - val_loss: 0.5239
# Epoch 285/500
#
# Epoch 00285: val_loss improved from 0.52386 to 0.52379, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5234 - val_loss: 0.5238
# Epoch 286/500
#
# Epoch 00286: val_loss improved from 0.52379 to 0.52372, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5234 - val_loss: 0.5237
# Epoch 287/500
#
# Epoch 00287: val_loss improved from 0.52372 to 0.52365, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5233 - val_loss: 0.5236
# Epoch 288/500
#
# Epoch 00288: val_loss improved from 0.52365 to 0.52358, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5232 - val_loss: 0.5236
# Epoch 289/500
#
# Epoch 00289: val_loss improved from 0.52358 to 0.52351, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5232 - val_loss: 0.5235
# Epoch 290/500
#
# Epoch 00290: val_loss improved from 0.52351 to 0.52344, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5231 - val_loss: 0.5234
# Epoch 291/500
#
# Epoch 00291: val_loss improved from 0.52344 to 0.52338, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5230 - val_loss: 0.5234
# Epoch 292/500
#
# Epoch 00292: val_loss improved from 0.52338 to 0.52331, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5229 - val_loss: 0.5233
# Epoch 293/500
#
# Epoch 00293: val_loss improved from 0.52331 to 0.52325, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5229 - val_loss: 0.5232
# Epoch 294/500
#
# Epoch 00294: val_loss improved from 0.52325 to 0.52318, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5228 - val_loss: 0.5232
# Epoch 295/500
#
# Epoch 00295: val_loss improved from 0.52318 to 0.52312, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5228 - val_loss: 0.5231
# Epoch 296/500
#
# Epoch 00296: val_loss improved from 0.52312 to 0.52305, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5227 - val_loss: 0.5231
# Epoch 297/500
#
# ...
# 60000/60000 - 1s - loss: 0.5170 - val_loss: 0.5174
# Epoch 403/500
#
# Epoch 00403: val_loss improved from 0.51743 to 0.51738, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5170 - val_loss: 0.5174
# Epoch 404/500
#
# Epoch 00404: val_loss improved from 0.51738 to 0.51733, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5169 - val_loss: 0.5173
# Epoch 405/500
#
# Epoch 00405: val_loss improved from 0.51733 to 0.51728, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5169 - val_loss: 0.5173
# Epoch 406/500
#
# Epoch 00406: val_loss improved from 0.51728 to 0.51723, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5168 - val_loss: 0.5172
# Epoch 407/500
#
# Epoch 00407: val_loss improved from 0.51723 to 0.51718, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5168 - val_loss: 0.5172
# Epoch 408/500
#
# Epoch 00408: val_loss improved from 0.51718 to 0.51714, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5167 - val_loss: 0.5171
# Epoch 409/500
#
# Epoch 00409: val_loss improved from 0.51714 to 0.51709, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5167 - val_loss: 0.5171
# Epoch 410/500
#
# Epoch 00410: val_loss improved from 0.51709 to 0.51704, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5166 - val_loss: 0.5170
# Epoch 411/500
#
# Epoch 00411: val_loss improved from 0.51704 to 0.51699, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5166 - val_loss: 0.5170
# Epoch 412/500
#
# Epoch 00412: val_loss improved from 0.51699 to 0.51694, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5166 - val_loss: 0.5169
# Epoch 413/500
#
# Epoch 00413: val_loss improved from 0.51694 to 0.51689, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5165 - val_loss: 0.5169
# Epoch 414/500
#
# Epoch 00414: val_loss improved from 0.51689 to 0.51684, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5165 - val_loss: 0.5168
# Epoch 415/500
#
# Epoch 00415: val_loss improved from 0.51684 to 0.51679, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5164 - val_loss: 0.5168
# Epoch 416/500
#
# Epoch 00416: val_loss improved from 0.51679 to 0.51674, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5164 - val_loss: 0.5167
# Epoch 417/500
#
# Epoch 00417: val_loss improved from 0.51674 to 0.51669, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5163 - val_loss: 0.5167
# Epoch 418/500
#
# Epoch 00418: val_loss improved from 0.51669 to 0.51664, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5163 - val_loss: 0.5166
# Epoch 419/500
#
# Epoch 00419: val_loss improved from 0.51664 to 0.51659, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5162 - val_loss: 0.5166
# Epoch 420/500
#
# Epoch 00420: val_loss improved from 0.51659 to 0.51655, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5162 - val_loss: 0.5165
# Epoch 421/500
#
# Epoch 00421: val_loss improved from 0.51655 to 0.51650, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5161 - val_loss: 0.5165
# Epoch 422/500
#
# Epoch 00422: val_loss improved from 0.51650 to 0.51645, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5161 - val_loss: 0.5164
# Epoch 423/500
#
# Epoch 00423: val_loss improved from 0.51645 to 0.51640, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5160 - val_loss: 0.5164
# Epoch 424/500
#
# Epoch 00424: val_loss improved from 0.51640 to 0.51635, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5160 - val_loss: 0.5163
# Epoch 425/500
#
# Epoch 00425: val_loss improved from 0.51635 to 0.51630, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5159 - val_loss: 0.5163
# Epoch 426/500
#
# Epoch 00426: val_loss improved from 0.51630 to 0.51625, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5159 - val_loss: 0.5162
# Epoch 427/500
#
# Epoch 00427: val_loss improved from 0.51625 to 0.51620, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5158 - val_loss: 0.5162
# Epoch 428/500
#
# Epoch 00428: val_loss improved from 0.51620 to 0.51615, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5158 - val_loss: 0.5161
# Epoch 429/500
#
# Epoch 00429: val_loss improved from 0.51615 to 0.51610, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5157 - val_loss: 0.5161
# Epoch 430/500
#
# Epoch 00430: val_loss improved from 0.51610 to 0.51605, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5157 - val_loss: 0.5160
# Epoch 431/500
#
# Epoch 00431: val_loss improved from 0.51605 to 0.51600, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5156 - val_loss: 0.5160
# Epoch 432/500
#
# Epoch 00432: val_loss improved from 0.51600 to 0.51595, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5156 - val_loss: 0.5160
# Epoch 433/500
#
# Epoch 00433: val_loss improved from 0.51595 to 0.51590, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5155 - val_loss: 0.5159
# Epoch 434/500
#
# Epoch 00434: val_loss improved from 0.51590 to 0.51585, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5155 - val_loss: 0.5159
# Epoch 435/500
#
# Epoch 00435: val_loss improved from 0.51585 to 0.51580, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5154 - val_loss: 0.5158
# Epoch 436/500
#
# Epoch 00436: val_loss improved from 0.51580 to 0.51575, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5154 - val_loss: 0.5158
# Epoch 437/500
#
# Epoch 00437: val_loss improved from 0.51575 to 0.51570, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5153 - val_loss: 0.5157
# Epoch 438/500
#
# Epoch 00438: val_loss improved from 0.51570 to 0.51565, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5153 - val_loss: 0.5156
# Epoch 439/500
#
# Epoch 00439: val_loss improved from 0.51565 to 0.51560, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5152 - val_loss: 0.5156
# Epoch 440/500
#
# Epoch 00440: val_loss improved from 0.51560 to 0.51555, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5152 - val_loss: 0.5155
# Epoch 441/500
#
# Epoch 00441: val_loss improved from 0.51555 to 0.51550, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5151 - val_loss: 0.5155
# Epoch 442/500
#
# Epoch 00442: val_loss improved from 0.51550 to 0.51545, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5151 - val_loss: 0.5154
# Epoch 443/500
#
# Epoch 00443: val_loss improved from 0.51545 to 0.51540, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5150 - val_loss: 0.5154
# Epoch 444/500
#
# Epoch 00444: val_loss improved from 0.51540 to 0.51535, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5150 - val_loss: 0.5153
# Epoch 445/500
#
# Epoch 00445: val_loss improved from 0.51535 to 0.51530, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5149 - val_loss: 0.5153
# Epoch 446/500
#
# Epoch 00446: val_loss improved from 0.51530 to 0.51525, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5149 - val_loss: 0.5152
# Epoch 447/500
#
# Epoch 00447: val_loss improved from 0.51525 to 0.51520, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5148 - val_loss: 0.5152
# Epoch 448/500
#
# Epoch 00448: val_loss improved from 0.51520 to 0.51514, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5147 - val_loss: 0.5151
# Epoch 449/500
#
# Epoch 00449: val_loss improved from 0.51514 to 0.51509, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5147 - val_loss: 0.5151
# Epoch 450/500
#
# Epoch 00450: val_loss improved from 0.51509 to 0.51504, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5146 - val_loss: 0.5150
# Epoch 451/500
#
# Epoch 00451: val_loss improved from 0.51504 to 0.51499, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5146 - val_loss: 0.5150
# Epoch 452/500
#
# Epoch 00452: val_loss improved from 0.51499 to 0.51494, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5145 - val_loss: 0.5149
# Epoch 453/500
#
# Epoch 00453: val_loss improved from 0.51494 to 0.51489, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5145 - val_loss: 0.5149
# Epoch 454/500
#
# Epoch 00454: val_loss improved from 0.51489 to 0.51484, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5144 - val_loss: 0.5148
# Epoch 455/500
#
# Epoch 00455: val_loss improved from 0.51484 to 0.51479, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5144 - val_loss: 0.5148
# Epoch 456/500
#
# Epoch 00456: val_loss improved from 0.51479 to 0.51473, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5143 - val_loss: 0.5147
# Epoch 457/500
#
# Epoch 00457: val_loss improved from 0.51473 to 0.51468, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5143 - val_loss: 0.5147
# Epoch 458/500
#
# Epoch 00458: val_loss improved from 0.51468 to 0.51463, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5142 - val_loss: 0.5146
# Epoch 459/500
#
# Epoch 00459: val_loss improved from 0.51463 to 0.51458, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5142 - val_loss: 0.5146
# Epoch 460/500
#
# Epoch 00460: val_loss improved from 0.51458 to 0.51453, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5141 - val_loss: 0.5145
# Epoch 461/500
#
# Epoch 00461: val_loss improved from 0.51453 to 0.51448, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5141 - val_loss: 0.5145
# Epoch 462/500
#
# Epoch 00462: val_loss improved from 0.51448 to 0.51442, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5140 - val_loss: 0.5144
# Epoch 463/500
#
# Epoch 00463: val_loss improved from 0.51442 to 0.51437, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5140 - val_loss: 0.5144
# Epoch 464/500
#
# Epoch 00464: val_loss improved from 0.51437 to 0.51432, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5139 - val_loss: 0.5143
# Epoch 465/500
#
# Epoch 00465: val_loss improved from 0.51432 to 0.51427, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5139 - val_loss: 0.5143
# Epoch 466/500
#
# Epoch 00466: val_loss improved from 0.51427 to 0.51421, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5138 - val_loss: 0.5142
# Epoch 467/500
#
# Epoch 00467: val_loss improved from 0.51421 to 0.51416, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5138 - val_loss: 0.5142
# Epoch 468/500
#
# Epoch 00468: val_loss improved from 0.51416 to 0.51411, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5137 - val_loss: 0.5141
# Epoch 469/500
#
# Epoch 00469: val_loss improved from 0.51411 to 0.51406, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5137 - val_loss: 0.5141
# Epoch 470/500
#
# Epoch 00470: val_loss improved from 0.51406 to 0.51400, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5136 - val_loss: 0.5140
# Epoch 471/500
#
# Epoch 00471: val_loss improved from 0.51400 to 0.51395, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5136 - val_loss: 0.5140
# Epoch 472/500
#
# Epoch 00472: val_loss improved from 0.51395 to 0.51390, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5135 - val_loss: 0.5139
# Epoch 473/500
#
# Epoch 00473: val_loss improved from 0.51390 to 0.51385, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5134 - val_loss: 0.5138
# Epoch 474/500
#
# Epoch 00474: val_loss improved from 0.51385 to 0.51379, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5134 - val_loss: 0.5138
# Epoch 475/500
#
# Epoch 00475: val_loss improved from 0.51379 to 0.51374, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5133 - val_loss: 0.5137
# Epoch 476/500
#
# Epoch 00476: val_loss improved from 0.51374 to 0.51369, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5133 - val_loss: 0.5137
# Epoch 477/500
#
# Epoch 00477: val_loss improved from 0.51369 to 0.51363, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5132 - val_loss: 0.5136
# Epoch 478/500
#
# Epoch 00478: val_loss improved from 0.51363 to 0.51358, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5132 - val_loss: 0.5136
# Epoch 479/500
#
# Epoch 00479: val_loss improved from 0.51358 to 0.51352, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5131 - val_loss: 0.5135
# Epoch 480/500
#
# Epoch 00480: val_loss improved from 0.51352 to 0.51347, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5131 - val_loss: 0.5135
# Epoch 481/500
#
# Epoch 00481: val_loss improved from 0.51347 to 0.51342, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5130 - val_loss: 0.5134
# Epoch 482/500
#
# Epoch 00482: val_loss improved from 0.51342 to 0.51336, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5130 - val_loss: 0.5134
# Epoch 483/500
#
# Epoch 00483: val_loss improved from 0.51336 to 0.51331, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5129 - val_loss: 0.5133
# Epoch 484/500
#
# Epoch 00484: val_loss improved from 0.51331 to 0.51325, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5129 - val_loss: 0.5133
# Epoch 485/500
#
# Epoch 00485: val_loss improved from 0.51325 to 0.51320, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5128 - val_loss: 0.5132
# Epoch 486/500
#
# Epoch 00486: val_loss improved from 0.51320 to 0.51315, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5127 - val_loss: 0.5131
# Epoch 487/500
#
# Epoch 00487: val_loss improved from 0.51315 to 0.51309, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5127 - val_loss: 0.5131
# Epoch 488/500
#
# Epoch 00488: val_loss improved from 0.51309 to 0.51304, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5126 - val_loss: 0.5130
# Epoch 489/500
#
# Epoch 00489: val_loss improved from 0.51304 to 0.51298, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5126 - val_loss: 0.5130
# Epoch 490/500
#
# Epoch 00490: val_loss improved from 0.51298 to 0.51293, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5125 - val_loss: 0.5129
# Epoch 491/500
#
# Epoch 00491: val_loss improved from 0.51293 to 0.51287, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5125 - val_loss: 0.5129
# Epoch 492/500
#
# Epoch 00492: val_loss improved from 0.51287 to 0.51282, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5124 - val_loss: 0.5128
# Epoch 493/500
#
# Epoch 00493: val_loss improved from 0.51282 to 0.51276, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5124 - val_loss: 0.5128
# Epoch 494/500
#
# Epoch 00494: val_loss improved from 0.51276 to 0.51271, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5123 - val_loss: 0.5127
# Epoch 495/500
#
# Epoch 00495: val_loss improved from 0.51271 to 0.51265, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5122 - val_loss: 0.5126
# Epoch 496/500
#
# Epoch 00496: val_loss improved from 0.51265 to 0.51259, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5122 - val_loss: 0.5126
# Epoch 497/500
#
# Epoch 00497: val_loss improved from 0.51259 to 0.51254, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5121 - val_loss: 0.5125
# Epoch 498/500
#
# Epoch 00498: val_loss improved from 0.51254 to 0.51248, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5121 - val_loss: 0.5125
# Epoch 499/500
#
# Epoch 00499: val_loss improved from 0.51248 to 0.51243, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5120 - val_loss: 0.5124
# Epoch 500/500
#
# Epoch 00500: val_loss improved from 0.51243 to 0.51237, saving model to model.weights.best.hdf5
# 60000/60000 - 1s - loss: 0.5120 - val_loss: 0.5124

# %%
# encode and decode some items
# note that we take them from the *test* set

autoencoder.load_weights('model.weights.best.hdf5' )
encoded_images = encoder.predict(x_test)
decoded_images = decoder.predict(encoded_images)

# %%
number_of_items = 12  # how many tems we will display
plt.figure(figsize=(20, 4))
for i in range(number_of_items):
    # display items before compression
    graph = plt.subplot(2, number_of_items, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    graph.get_xaxis().set_visible(False)
    graph.get_yaxis().set_visible(False)

    # display items after decompression
    graph = plt.subplot(2, number_of_items, i + 1 + number_of_items)
    plt.imshow(decoded_images[i].reshape(28, 28))
    plt.gray()
    graph.get_xaxis().set_visible(False)
    graph.get_yaxis().set_visible(False)
plt.show()
