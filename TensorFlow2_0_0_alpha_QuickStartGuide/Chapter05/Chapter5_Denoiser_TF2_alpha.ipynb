# %%
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.callbacks import TensorBoard
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
(train_x, _), (test_x, _) = fashion_mnist.load_data()

train_x = train_x.astype('float32') / 255.
test_x = test_x.astype('float32') / 255.

print(train_x.shape)
print(test_x.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
train_x = np.reshape(train_x, (len(train_x), 28, 28, 1))
test_x = np.reshape(test_x, (len(test_x), 28, 28, 1))

print(train_x.shape)
print(test_x.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %%
noise = 0.5
train_x_noisy = train_x + noise * np.random.normal(loc=0.0, scale=1.0, size=train_x.shape)
test_x_noisy = test_x + noise * np.random.normal(loc=0.0, scale=1.0, size=test_x.shape)

train_x_noisy = np.clip(train_x_noisy, 0., 1.)
test_x_noisy = np.clip(test_x_noisy, 0., 1.)

# %%
number_of_items = 10
plt.figure(figsize=(20, 2))

for i in range(number_of_items):
    display = plt.subplot(1, number_of_items,i+1)
    plt.imshow(test_x[i].reshape(28, 28))
    plt.gray()
    display.get_xaxis().set_visible(False)
    display.get_yaxis().set_visible(False)

# %%
plt.figure(figsize=(20, 2))
for i in range(number_of_items):
    display = plt.subplot(1, number_of_items,i+1)
    plt.imshow(test_x_noisy[i].reshape(28, 28))
    plt.gray()
    display.get_xaxis().set_visible(False)
    display.get_yaxis().set_visible(False)
plt.show()

# %%
input_image = Input(shape=(28, 28, 1))
print(input_image.shape)
im = Conv2D(32, (3, 3), activation='relu', padding='same')(input_image)
print(im.shape)
im = MaxPooling2D((2, 2), padding='same')(im)
print(im.shape)
im = Conv2D(32, (3, 3), activation='relu', padding='same')(im)
print(im.shape)
encoded = MaxPooling2D((2, 2), padding='same')(im)
print(encoded.shape)
# at this point the representation is (7, 7, 32)

im = Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
print(im.shape)
im = UpSampling2D((2, 2))(im)
print(im.shape)
im = Conv2D(32, (3, 3), activation='relu', padding='same')(im)
print(im.shape)
im = UpSampling2D((2, 2))(im)
print(im.shape)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(im)
print(decoded.shape)

autoencoder = Model(inputs=input_image, outputs=decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
# Out:
# (None, 28, 28, 1)
# (None, 28, 28, 32)
# (None, 14, 14, 32)
# (None, 14, 14, 32)
# (None, 7, 7, 32)
# (None, 7, 7, 32)
# (None, 14, 14, 32)
# (None, 14, 14, 32)
# (None, 28, 28, 32)
# (None, 28, 28, 1)

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 32)          9248
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 1)         289
# =================================================================
# Total params: 28,353
# Trainable params: 28,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
tb = [TensorBoard(log_dir='./tmp/tb', write_graph=True)]
epochs = 10 # for testing, set to 150 for actual training, best speed on GPU
batch_size = 128
autoencoder.fit(train_x_noisy, train_x,
                epochs=epochs,
                batch_size=batch_size,
                shuffle=True,
                validation_data=(test_x_noisy, test_x),
                callbacks=tb)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 28s 470us/sample - loss: 0.5597 - val_loss: 0.5432
# Epoch 2/100
# 60000/60000 [==============================] - 28s 470us/sample - loss: 0.5217 - val_loss: 0.5014
# Epoch 3/100
# 60000/60000 [==============================] - 28s 464us/sample - loss: 0.4788 - val_loss: 0.4599
# Epoch 4/100
# 60000/60000 [==============================] - 28s 465us/sample - loss: 0.4425 - val_loss: 0.4305
# Epoch 5/100
# 60000/60000 [==============================] - 28s 466us/sample - loss: 0.4202 - val_loss: 0.4148
# Epoch 6/100
# 60000/60000 [==============================] - 28s 459us/sample - loss: 0.4084 - val_loss: 0.4060
# Epoch 7/100
# 60000/60000 [==============================] - 28s 459us/sample - loss: 0.4011 - val_loss: 0.4000
# Epoch 8/100
# 60000/60000 [==============================] - 27s 458us/sample - loss: 0.3957 - val_loss: 0.3951
# Epoch 9/100
# 60000/60000 [==============================] - 27s 458us/sample - loss: 0.3913 - val_loss: 0.3910
# Epoch 10/100
# 60000/60000 [==============================] - 27s 458us/sample - loss: 0.3873 - val_loss: 0.3873
# Epoch 11/100
# 60000/60000 [==============================] - 28s 458us/sample - loss: 0.3838 - val_loss: 0.3840
# Epoch 12/100
# 60000/60000 [==============================] - 27s 458us/sample - loss: 0.3807 - val_loss: 0.3810
# Epoch 13/100
# 60000/60000 [==============================] - 28s 464us/sample - loss: 0.3779 - val_loss: 0.3783
# Epoch 14/100
# 60000/60000 [==============================] - 28s 462us/sample - loss: 0.3753 - val_loss: 0.3759
# Epoch 15/100
# 60000/60000 [==============================] - 28s 471us/sample - loss: 0.3730 - val_loss: 0.3736
# Epoch 16/100
# 60000/60000 [==============================] - 29s 479us/sample - loss: 0.3708 - val_loss: 0.3715
# Epoch 17/100
# 60000/60000 [==============================] - 28s 468us/sample - loss: 0.3688 - val_loss: 0.3696
# Epoch 18/100
# 60000/60000 [==============================] - 28s 468us/sample - loss: 0.3669 - val_loss: 0.3677
# Epoch 19/100
# 60000/60000 [==============================] - 28s 469us/sample - loss: 0.3652 - val_loss: 0.3661
# Epoch 20/100
# 60000/60000 [==============================] - 28s 470us/sample - loss: 0.3636 - val_loss: 0.3645
# Epoch 21/100
# 60000/60000 [==============================] - 28s 465us/sample - loss: 0.3620 - val_loss: 0.3629
# Epoch 22/100
# 60000/60000 [==============================] - 28s 467us/sample - loss: 0.3605 - val_loss: 0.3615
# Epoch 23/100
# 60000/60000 [==============================] - 29s 476us/sample - loss: 0.3592 - val_loss: 0.3602
# Epoch 24/100
# 60000/60000 [==============================] - 28s 471us/sample - loss: 0.3579 - val_loss: 0.3589
# Epoch 25/100
# 60000/60000 [==============================] - 28s 468us/sample - loss: 0.3567 - val_loss: 0.3577
# Epoch 26/100
# 60000/60000 [==============================] - 28s 468us/sample - loss: 0.3555 - val_loss: 0.3567
# Epoch 27/100
# 60000/60000 [==============================] - 28s 464us/sample - loss: 0.3545 - val_loss: 0.3556
# Epoch 28/100
# 60000/60000 [==============================] - 28s 469us/sample - loss: 0.3535 - val_loss: 0.3547
# Epoch 29/100
# 60000/60000 [==============================] - 28s 465us/sample - loss: 0.3525 - val_loss: 0.3537
# Epoch 30/100
# 60000/60000 [==============================] - 28s 460us/sample - loss: 0.3517 - val_loss: 0.3529
# Epoch 31/100
# 60000/60000 [==============================] - 28s 466us/sample - loss: 0.3508 - val_loss: 0.3521
# Epoch 32/100
# 60000/60000 [==============================] - 28s 464us/sample - loss: 0.3500 - val_loss: 0.3513
# Epoch 33/100
# 60000/60000 [==============================] - 28s 468us/sample - loss: 0.3493 - val_loss: 0.3506
# Epoch 34/100
# 60000/60000 [==============================] - 28s 473us/sample - loss: 0.3486 - val_loss: 0.3500
# Epoch 35/100
# 60000/60000 [==============================] - 28s 464us/sample - loss: 0.3480 - val_loss: 0.3493
# Epoch 36/100
# 60000/60000 [==============================] - 28s 459us/sample - loss: 0.3473 - val_loss: 0.3487
# Epoch 37/100
# 60000/60000 [==============================] - 28s 460us/sample - loss: 0.3467 - val_loss: 0.3481
# Epoch 38/100
# 60000/60000 [==============================] - 28s 464us/sample - loss: 0.3462 - val_loss: 0.3476
# Epoch 39/100
# 60000/60000 [==============================] - 28s 463us/sample - loss: 0.3456 - val_loss: 0.3471
# Epoch 40/100
# 60000/60000 [==============================] - 28s 465us/sample - loss: 0.3451 - val_loss: 0.3466
# Epoch 41/100
# 60000/60000 [==============================] - 28s 462us/sample - loss: 0.3446 - val_loss: 0.3461
# Epoch 42/100
# 60000/60000 [==============================] - 28s 464us/sample - loss: 0.3441 - val_loss: 0.3456
# Epoch 43/100
# 60000/60000 [==============================] - 28s 463us/sample - loss: 0.3437 - val_loss: 0.3452
# Epoch 44/100
# 60000/60000 [==============================] - 28s 459us/sample - loss: 0.3433 - val_loss: 0.3448
# Epoch 45/100
# 60000/60000 [==============================] - 28s 460us/sample - loss: 0.3428 - val_loss: 0.3444
# Epoch 46/100
# 60000/60000 [==============================] - 28s 461us/sample - loss: 0.3424 - val_loss: 0.3440
# Epoch 47/100
# 60000/60000 [==============================] - 28s 464us/sample - loss: 0.3420 - val_loss: 0.3436
# Epoch 48/100
# 60000/60000 [==============================] - 28s 466us/sample - loss: 0.3417 - val_loss: 0.3432
# Epoch 49/100
# 60000/60000 [==============================] - 28s 463us/sample - loss: 0.3413 - val_loss: 0.3429
# Epoch 50/100
# 60000/60000 [==============================] - 28s 464us/sample - loss: 0.3410 - val_loss: 0.3425
# Epoch 51/100
# 60000/60000 [==============================] - 28s 465us/sample - loss: 0.3406 - val_loss: 0.3422
# Epoch 52/100
# 60000/60000 [==============================] - 28s 463us/sample - loss: 0.3403 - val_loss: 0.3419
# Epoch 53/100
# 60000/60000 [==============================] - 28s 472us/sample - loss: 0.3400 - val_loss: 0.3416
# Epoch 54/100
# 60000/60000 [==============================] - 28s 472us/sample - loss: 0.3397 - val_loss: 0.3413
# Epoch 55/100
# 60000/60000 [==============================] - 28s 472us/sample - loss: 0.3394 - val_loss: 0.3410
# Epoch 56/100
# 60000/60000 [==============================] - 29s 476us/sample - loss: 0.3391 - val_loss: 0.3407
# Epoch 57/100
# 60000/60000 [==============================] - 28s 473us/sample - loss: 0.3388 - val_loss: 0.3405
# Epoch 58/100
# 60000/60000 [==============================] - 28s 475us/sample - loss: 0.3385 - val_loss: 0.3402
# Epoch 59/100
# 60000/60000 [==============================] - 28s 474us/sample - loss: 0.3383 - val_loss: 0.3399
# Epoch 60/100
# 60000/60000 [==============================] - 28s 474us/sample - loss: 0.3380 - val_loss: 0.3397
# Epoch 61/100
# 60000/60000 [==============================] - 28s 474us/sample - loss: 0.3378 - val_loss: 0.3394
# Epoch 62/100
# 60000/60000 [==============================] - 28s 472us/sample - loss: 0.3375 - val_loss: 0.3392
# Epoch 63/100
# 60000/60000 [==============================] - 28s 472us/sample - loss: 0.3373 - val_loss: 0.3390
# Epoch 64/100
# 60000/60000 [==============================] - 29s 476us/sample - loss: 0.3370 - val_loss: 0.3387
# Epoch 65/100
# 60000/60000 [==============================] - 29s 475us/sample - loss: 0.3368 - val_loss: 0.3385
# Epoch 66/100
# 60000/60000 [==============================] - 28s 469us/sample - loss: 0.3366 - val_loss: 0.3383
# Epoch 67/100
# 60000/60000 [==============================] - 29s 477us/sample - loss: 0.3364 - val_loss: 0.3381
# Epoch 68/100
# 60000/60000 [==============================] - 28s 472us/sample - loss: 0.3361 - val_loss: 0.3378
# Epoch 69/100
# 60000/60000 [==============================] - 28s 473us/sample - loss: 0.3359 - val_loss: 0.3376
# Epoch 70/100
# 60000/60000 [==============================] - 28s 469us/sample - loss: 0.3357 - val_loss: 0.3374
# Epoch 71/100
# 60000/60000 [==============================] - 28s 468us/sample - loss: 0.3355 - val_loss: 0.3372
# Epoch 72/100
# 60000/60000 [==============================] - 28s 472us/sample - loss: 0.3353 - val_loss: 0.3370
# Epoch 73/100
# 60000/60000 [==============================] - 28s 474us/sample - loss: 0.3351 - val_loss: 0.3368
# Epoch 74/100
# 60000/60000 [==============================] - 28s 464us/sample - loss: 0.3349 - val_loss: 0.3366
# Epoch 75/100
# 60000/60000 [==============================] - 28s 466us/sample - loss: 0.3347 - val_loss: 0.3364
# Epoch 76/100
# 60000/60000 [==============================] - 28s 461us/sample - loss: 0.3345 - val_loss: 0.3362
# Epoch 77/100
# 60000/60000 [==============================] - 28s 470us/sample - loss: 0.3343 - val_loss: 0.3360
# Epoch 78/100
# 60000/60000 [==============================] - 28s 467us/sample - loss: 0.3341 - val_loss: 0.3358
# Epoch 79/100
# 60000/60000 [==============================] - 28s 460us/sample - loss: 0.3339 - val_loss: 0.3357
# Epoch 80/100
# 60000/60000 [==============================] - 28s 463us/sample - loss: 0.3337 - val_loss: 0.3355
# Epoch 81/100
# 60000/60000 [==============================] - 28s 462us/sample - loss: 0.3335 - val_loss: 0.3353
# Epoch 82/100
# 60000/60000 [==============================] - 28s 462us/sample - loss: 0.3334 - val_loss: 0.3351
# Epoch 83/100
# 60000/60000 [==============================] - 28s 465us/sample - loss: 0.3332 - val_loss: 0.3349
# Epoch 84/100
# 60000/60000 [==============================] - 28s 468us/sample - loss: 0.3330 - val_loss: 0.3348
# Epoch 85/100
# 60000/60000 [==============================] - 28s 463us/sample - loss: 0.3328 - val_loss: 0.3346
# Epoch 86/100
# 60000/60000 [==============================] - 28s 467us/sample - loss: 0.3327 - val_loss: 0.3344
# Epoch 87/100
# 60000/60000 [==============================] - 28s 467us/sample - loss: 0.3325 - val_loss: 0.3343
# Epoch 88/100
# 60000/60000 [==============================] - 28s 466us/sample - loss: 0.3324 - val_loss: 0.3341
# Epoch 89/100
# 60000/60000 [==============================] - 28s 461us/sample - loss: 0.3322 - val_loss: 0.3340
# Epoch 90/100
# 60000/60000 [==============================] - 27s 458us/sample - loss: 0.3320 - val_loss: 0.3338
# Epoch 91/100
# 60000/60000 [==============================] - 28s 462us/sample - loss: 0.3319 - val_loss: 0.3337
# Epoch 92/100
# 60000/60000 [==============================] - 31s 512us/sample - loss: 0.3317 - val_loss: 0.3335
# Epoch 93/100
# 60000/60000 [==============================] - 33s 547us/sample - loss: 0.3316 - val_loss: 0.3334
# Epoch 94/100
# 60000/60000 [==============================] - 33s 545us/sample - loss: 0.3314 - val_loss: 0.3332
# Epoch 95/100
# 60000/60000 [==============================] - 33s 547us/sample - loss: 0.3313 - val_loss: 0.3331
# Epoch 96/100
# 60000/60000 [==============================] - 33s 546us/sample - loss: 0.3311 - val_loss: 0.3329
# Epoch 97/100
# 60000/60000 [==============================] - 33s 553us/sample - loss: 0.3310 - val_loss: 0.3328
# Epoch 98/100
# 60000/60000 [==============================] - 33s 555us/sample - loss: 0.3308 - val_loss: 0.3326
# Epoch 99/100
# 60000/60000 [==============================] - 33s 552us/sample - loss: 0.3307 - val_loss: 0.3325
# Epoch 100/100
# 60000/60000 [==============================] - 34s 561us/sample - loss: 0.3305 - val_loss: 0.3323

# %%
decoded_images = autoencoder.predict(test_x_noisy)
number_of_items = 10
plt.figure(figsize=(20, 2))
for item in range(number_of_items):
    display = plt.subplot(1, number_of_items,item+1)
    im = decoded_images[item].reshape(28, 28)
    plt.imshow(im)
    plt.gray()
    display.get_xaxis().set_visible(False)
    display.get_yaxis().set_visible(False)
plt.show()
